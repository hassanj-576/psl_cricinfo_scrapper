# %%
import requests
from urllib.parse import urlparse
from bs4 import BeautifulSoup
import json
from furl import furl
from collections import defaultdict
import pandas as pd
import copy
import time
from tqdm import tqdm

# %%
# URL to result pages of all the years of PSL
# You can replace these with URLS to some other series result pages and the script should worl
psl_urls = {
    "2016":"https://www.espncricinfo.com/series/pakistan-super-league-2015-16-923069/match-results",
    "2017":"https://www.espncricinfo.com/series/psl-2016-17-1075974/match-results",
    "2018":"https://www.espncricinfo.com/series/psl-2017-18-1128817/match-results",
    "2019":"https://www.espncricinfo.com/series/psl-2018-19-1168814/match-results",
    "2020":"https://www.espncricinfo.com/series/psl-2019-20-2020-21-1211602/match-results",
    "2021":"https://www.espncricinfo.com/series/psl-2020-21-2021-1238103/match-schedule-fixtures-and-results"
}

# %%
# Extracting all Data
start = time.time()
all_rows = []
for psl_year, url in psl_urls.items():
    psl_data = get_psl_data_for_year(psl_year, url)
    all_rows.extend(psl_data)
end = time.time()

print (f"Total Time Taken : {end-start}")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [13], in <cell line: 4>()
#       3 all_rows = []
#       4 for psl_year, url in psl_urls.items():
# ----> 5     psl_data = get_psl_data_for_year(psl_year, url)
#       6     all_rows.extend(psl_data)
#       7 end = time.time()
#
# Input In [12], in get_psl_data_for_year(psl_year, url)
#       2 def get_psl_data_for_year(psl_year, url):
# ----> 3     url_list = get_all_url_for_psl_url(url)
#       4     all_match_data = get_all_matches_data_from_url_list(url_list)
#       5     with open (f"psl_{psl_year}.json","w")as f:
#
# Input In [6], in get_all_url_for_psl_url(url)
#       3 content = requests.get(url).text
#       4 soup = BeautifulSoup(content)
# ----> 5 main_div = soup.find("div",{"class":"league-scores-container"}).find("div",{"class":"no-gutters"})
#       6 url_list = []
#       7 for div in main_div:
#
# AttributeError: 'NoneType' object has no attribute 'find'

# %%
# Converting to Dataframe
df = pd.DataFrame(all_rows)

# %%
# Saving Dataframe
df.to_csv("psl.csv",index=False)

# %%
def get_psl_data_for_year(psl_year, url):
    print(f"Getting Data for year {psl_year}")
    url_list = get_all_url_for_psl_url(url)
    all_match_data = get_all_matches_data_from_url_list(url_list)
    with open(f"psl_{psl_year}.json", "w") as f:
        json.dump(all_match_data, f)
    print(f" JSON DUMP DATA LEN : {len(all_match_data)}")
    return get_row_list_from_all_match_data(all_match_data, psl_year)

# %%
def get_all_url_for_psl_url(url):
    content = requests.get(url).text
    soup = BeautifulSoup(content, "html.parser")
    main_div = soup.find("div", {"class": "ds-p-0"})
    url_list = []
    for div in main_div:
        wrong_url = div.find("a")["href"]
        url = f"https://www.espncricinfo.com{wrong_url}"
        url_list.append(url)
    return url_list

# %%
def get_all_matches_data_from_url_list(url_list):
    all_match_data = []
    for match_url in tqdm(["https://www.espncricinfo.com/series/psl-2019-20-2020-21-1211602/karachi-kings-vs-lahore-qalandars-final-1231146/full-scorecard"]):
        print(match_url)
        url_split = match_url.split("/")
        series_id = url_split[4].split("-")[-1]
        match_id = url_split[5].split("-")[-1]
        match_data = defaultdict(int)
        team1, team2, result = get_winner_name(match_url)
        for inning_number in range(1, 3):
            score_url = f"https://hs-consumer-api.espncricinfo.com/v1/pages/match/comments?seriesId={series_id}&matchId={match_id}&inningNumber={inning_number}&commentType=ALL"
            match_data[inning_number] = get_data_for_url(score_url)
        all_match_data.append(
            {"team_1": team1, "team_2": team2, "result": result, "data": match_data}
        )
    return all_match_data

# %%
def get_winner_name(url):
    content = requests.get(url).text
    soup = BeautifulSoup(content, "html.parser")
    match_info = soup.find(
        "div", {"class": "ds-text-compact-xxs ds-p-2 ds-px-4 lg:ds-py-3"}
    )
    winner = match_info.find(
        "p", {"class": "ds-text-tight-m ds-font-regular ds-truncate ds-text-typo-title"}
    )
    teams = match_info.find(
        "div", {"class": "ds-flex ds-flex-col ds-mt-3 md:ds-mt-0 ds-mt-0 ds-mb-1"}
    )
    team1, team2 = teams.find_all(
        "a", {"class": "ds-inline-flex ds-items-start ds-leading-none"}
    )
    team1 = team1.text
    team2 = team2.text
    if "abandoned" in winner.text:
        return team1, team2, "abondoned"
    elif "tied" in winner.text:
        return team1, team2, "tied"
    elif "No result" in winner.text:
        return team1, team2, "no_result"
    else:
        return team1, team2, winner.text.split(" ")[0]

# %%
def get_data_for_url(url):
    overs = defaultdict(list)
    previous_over = 20
    next_over = "stuf"
    while next_over:
        content = requests.get(url)
        next_over = content.json().get("nextInningOver")
        json_data = content.json()
        for comment in json_data.get("comments"):
            over = comment.get("overNumber")
            wicket_text = comment.get("dismissalText")
            if wicket_text:
                wicket_text = wicket_text.get("short")
            ball_obj = {
                "ball": comment.get("ballNumber"),
                "runs": comment.get("totalRuns"),
                "is_four": comment.get("isFour"),
                "is_six": comment.get("isSix"),
                "is_wicket": comment.get("isWicket"),
                "wicket": comment.get("dismissalType"),
                "wicket_text": wicket_text,
            }
            overs[over].append(ball_obj)
        if f"fromInningOver={previous_over}" in url:

            url = url.replace(
                f"fromInningOver={previous_over}", f"fromInningOver={next_over}"
            )
        else:
            url = f"{url}&fromInningOver={next_over}"

        previous_over = next_over

    return overs

# %%
def get_row_list_from_all_match_data(all_match_data, psl_year):
    all_rows = []
    for index, match in enumerate(reversed(all_match_data)):
        for ining, value in match["data"].items():
            wickets = 0
            runs = 0
            for over in range(1, 21):
                if over in value:
                    for ball_result in reversed(value[over]):
                        row = {}
                        runs = runs + (ball_result["runs"])
                        ball = ball_result["ball"]
                        if ball_result["is_wicket"]:
                            wickets += 1
                        row = copy.deepcopy(ball_result)
                        row["psl_year"] = psl_year
                        row["match_number"] = index + 1
                        row["over"] = over
                        row["inning"] = ining
                        row["team_1"] = match["team_1"]
                        row["team_2"] = match["team_2"]
                        row["result"] = match["result"]
                        row["total_runs"] = runs
                        row["wickets"] = wickets
                        all_rows.append(row)
    return all_rows

# %%
a =get_all_matches_data_from_url_list([])
# Out:
#   0%|                                                                                                                                                                                           | 0/1 [00:00<?, ?it/s]
# https://www.espncricinfo.com/series/psl-2019-20-2020-21-1211602/karachi-kings-vs-lahore-qalandars-final-1231146/full-scorecard
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:29<00:00, 29.83s/it]

# %%
a
# Out:
# [{'team_1': 'Lahore Qalandars',
#   'team_2': 'Karachi Kings',
#   'result': 'Kings',
#   'data': defaultdict(int,
#               {1: defaultdict(list,
#                            {20: [{'ball': 6,
#                               'runs': 2,
#                               'is_four': False,
#                               'is_six': False,
#                               'is_wicket': False,
#                               'wicket': None,
#                               'wicket_text': None},
#                              {'ball': 5,
#                               'runs': 4,
#                               'is_four': True,
#                               'is_six': False,
#                               'is_wicket': False,
#                               'wicket': None,
#                               'wicket_text': None},
#                              {'ball': 4,
#                               'runs': 1,
#                               'is_four': False,
#                               'is_six': False,
#                               'is_wicket': False,
#                               'wicket': None,
#                               'wicket_text': None},
#                              {'ball': 3,
#                               'runs': 1,
#                               'is_four': False,
#                               'is_six': False,
#                               'is_wicket': False,
#                               'wicket': None,
#                               'wicket_text': None},
#                              {'ball': 2,
#                               'runs': 6,
#                               'is_four': False,
#                               'is_six': True,
#                               'is_wicket': False,
#                               'wicket': None,
#                               'wicket_text': None},
#                              {'ball': 1,
#                               'runs': 1,
#                               'is_four': False,
#                               'is_six': False,
#                               'is_wicket': False,
#                               'wicket': None,
#                               'wicket_text': None}],
#                             19: [{'ball': 7,
#                               'runs': 1,
#                               'is_four': False,
#                               'is_six': False,
#                               'is_wicket': False,
#                               'wicket': None,
#                               'wicket_text': None},
#                              {'ball': 6,
#                               'runs': 0,
#                               'is_four': False,
#                               'is_six': False,
#                               'is_wicket': True,
#                               'wicket': 1,
#                               'wicket_text': 'caught'},
#                              {'ball': 5,
#                               'runs': 1,
#                               'is_four': False,
#                               'is_six': False,
#                               'is_wicket': False,
#                               'wicket': None,
#                               'wicket_text': None},
#                              {'ball': 4,
#                               'runs': 2,
#                               'is_four': False,
#                               'is_six': False,
#                               'is_wicket': False,
#                               'wicket': None,
#                               'wicket_text': None},
#                              {'ball': 3,
#                               'runs': 4,
#                               'is_four': False,
#                               'is_six': False,
#                               'is_wicket': False,
#                               'wicket': None,
#                               'wicket_text': None},
#                              {'ball': 2,
#                               'runs': 1,
#                               'is_four': False,
#                               'is_six': False,
#                               'is_wicket': False,
#                               'wicket': None,
#                               'wicket_text': None},
#                              {'ball': 1,
#                               'runs': 0,
#                               'is_four': False,
#                               'is_six': False,
#                               'is_wicket': True,
#                               'wicket': 1,
#                               'wicket_text': 'caught'}],
#                             18: [{'ball': 6,
#                               'runs': 1,
#                               'is_four': False,
#                               'is_six': False,
#                               'is_wicket': False,
#                               'wicket': None,
#                               'wicket_text': None},
#                              {'ball': 5,
#                               'runs': 2,
#                               'is_four': False,
#                               'is_six': False,
#                               'is_wicket': False,
#                               'wicket': None,
#                               'wicket_text': None},
#                              {'ball': 4,
#                               'runs': 0,
#                               'is_four': False,
#                               'is_six': False,
#                               'is_wicket': False,
#                               'wicket': None,
#                               'wicket_text': None},
#                              {'ball': 3,
#                               'runs': 1,
#                               'is_four': False,
#                               'is_six': False,
#                               'is_wicket': False,
#                               'wicket': None,
#                               'wicket_text': None},
#                              {'ball': 2,
#                               'runs': 1,
#                               'is_four': False,
#                               'is_six': False,
#                               'is_wicket': False,
#                               'wicket': None,
#                               'wicket_text': None},
#                              {'ball': 1,
#                               'runs': 1,
#                               'is_four': False,
#                               'is_six': False,
#                               'is_wicket': False,
#                               'wicket': None,
#                               'wicket_text': None}],
#                             17: [{'ball': 6,
#                               'runs': 0,
#                               'is_four': False,
#                               'is_six': False,
#                               'is_wicket': False,
#                               'wicket': None,
#                               'wicket_text': None},
#                              {'ball': 5,
#                               'runs': 0,
#                               'is_four': False,
#                               'is_six': False,
#                               'is_wicket': False,
#                               'wicket': None,
#                               'wicket_text': None},
#                              {'ball': 4,
#                               'runs': 1,
#                               'is_four': False,
#                               'is_six': False,
#                               'is_wicket': False,
#                               'wicket': None,
#                               'wicket_text': None},
#                              {'ball': 3,
#                               'runs': 0,
#                               'is_four': False,
#                               'is_six': False,
#                               'is_wicket': False,
#                               'wicket': None,
#                               'wicket_text': None},
#                              {'ball': 2,
#                               'runs': 0,
#                               'is_four': False,
#                               'is_six': False,
#                               'is_wicket': False,
#                               'wicket': None,
#                               'wicket_text': None},
#                              {'ball': 1,
#                               'runs': 4,
#                               'is_four': True,
#                               'is_six': False,
#                               'is_wicket': False,
#                               'wicket': None,
#                               'wicket_text': None}],
#                             16: [{'ball': 6,
#                               'runs': 1,
#                               'is_four': False,
#                               'is_six': False,
#                               'is_wicket': False,
#                               'wicket': None,
#                               'wicket_text': None},
#                              {'ball': 5,
#                               'runs': 1,
#                               'is_four': False,
#                               'is_six': False,
#                               'is_wicket': False,
#                               'wicket': None,
#                               'wicket_text': None},
#                              {'ball': 4,
#                               'runs': 0,
#                               'is_four': False,
#                               'is_six': False,
#                               'is_wicket': True,
#                               'wicket': 1,
#                               'wicket_text': 'caught'},
#                              {'ball': 3,
#                               'runs': 1,
#                               'is_four': False,
#                               'is_six': False,
#                               'is_wicket': False,
#                               'wicket': None,
#                               'wicket_text': None},
#                              {'ball': 2,
#                               'runs': 1,
#                               'is_four': False,
#                               'is_six': False,
#                               'is_wicket': False,
#                               'wicket': None,
#                               'wicket_text': None},
#                              {'ball': 1,
#                               'runs': 1,
#                               'is_four': False,
#                               'is_six': False,
#                               'is_wicket': False,
#                               'wicket': None,
#                               'wicket_text': None}],
#                             15: [{'ball': 6,
#                               'runs': 0,
#                               'is_four': False,
#                               'is_six': False,
#                               'is_wicket': False,
#                               'wicket': None,
#                               'wicket_text': None},
#                              {'ball': 5,
#                               'runs': 0,
#                               'is_four': False,
#                               'is_six': False,
#                               'is_wicket': False,
#                               'wicket': None,
#                               'wicket_text': None},
#                              {'ball': 4,
#                               'runs': 4,
#                               'is_four': True,
#                               'is_six': False,
#                               'is_wicket': False,
#                               'wicket': None,
#                               'wicket_text': None},
#                              {'ball': 3,
#                               'runs': 1,
#                               'is_four': False,
#                               'is_six': False,
#                               'is_wicket': False,
#                               'wicket': None,
#                               'wicket_text': None},
#                              {'ball': 2,
#                               'runs': 0,
#                               'is_four': False,
#                               'is_six': False,
#                               'is_wicket': False,
#                               'wicket': None,
#                               'wicket_text': None},
#                              {'ball': 1,
#                               'runs': 1,
#                               'is_four': False,
#                               'is_six': False,
#                               'is_wicket': False,
#                               'wicket': None,
#                               'wicket_text': None}],
#                             14: [{'ball': 6,
#                               'runs': 2,
#                               'is_four': False,
#                               'is_six': False,
#                               'is_wicket': False,
#                               'wicket': None,
#                               'wicket_text': None},
#                              {'ball': 5,
#                               'runs': 4,
#                               'is_four': True,
#                               'is_six': False,
#                               'is_wicket': False,
#                               'wicket': None,
#                               'wicket_text': None},
#                              {'ball': 4,
#                               'runs': 1,
#                               'is_four': False,
#                               'is_six': False,
#                               'is_wicket': False,
#                               'wicket': None,
#                               'wicket_text': None},
#                              {'ball': 3,
#                               'runs': 0,
#                               'is_four': False,
#                               'is_six': False,
#                               'is_wicket': True,
#                               'wicket': 1,
#                               'wicket_text': 'caught'},
#                              {'ball': 2,
#                               'runs': 2,
#                               'is_four': False,
#                               'is_six': False,
#                               'is_wicket': False,
#                               'wicket': None,
#                               'wicket_text': None},
#                              {'ball': 1,
#                               'runs': 1,
#                               'is_four': False,
#                               'is_six': False,
#                               'is_wicket': False,
#                               'wicket': None,
#                               'wicket_text': None}],
#                             13: [{'ball': 6,
#                               'runs': 1,
#                               'is_four': False,
#                               'is_six': False,
#                               'is_wicket': False,
#                               'wicket': None,
#                               'wicket_text': None},
#                              {'ball': 5,
#                               'runs': 1,
#                               'is_four': False,
#                               'is_six': False,
#                               'is_wicket': False,
#                               'wicket': None,
#                               'wicket_text': None},
#                              {'ball': 4,
#                               'runs': 1,
#                               'is_four': False,
#                               'is_six': False,
#                               'is_wicket': False,
#                               'wicket': None,
#                               'wicket_text': None},
#                              {'ball': 3,
#                               'runs': 1,
#                               'is_four': False,
#                               'is_six': False,
#                               'is_wicket': False,
#                               'wicket': None,
#                               'wicket_text': None},
#                              {'ball': 2,
#                               'runs': 1,
#                               'is_four': False,
#                               'is_six': False,
#                               'is_wicket': False,
#                               'wicket': None,
#                               'wicket_text': None},
#                              {'ball': 1,
#                               'runs': 1,
#                               'is_four': False,
#                               'is_six': False,
#                               'is_wicket': False,
#                               'wicket': None,
#                               'wicket_text': None}],
#                             12: [{'ball': 6,
#                               'runs': 0,
#                               'is_four': False,
#                               'is_six': False,
#                               'is_wicket': False,
#                               'wicket': None,
#                               'wicket_text': None},
#                              {'ball': 5,
#                               'runs': 1,
#                               'is_four': False,
#                               'is_six': False,
#                               'is_wicket': False,
#                               'wicket': None,
#                               'wicket_text': None},
#                              {'ball': 4,
#                               'runs': 0,
#                               'is_four': False,
#                               'is_six': False,
#                               'is_wicket': False,
#                               'wicket': None,
#                               'wicket_text': None},
#                              {'ball': 3,
#                               'runs': 0,
#                               'is_four': False,
#                               'is_six': False,
#                               'is_wicket': False,
#                               'wicket': None,
#                               'wicket_text': None},
#                              {'ball': 2,
#                               'runs': 1,
#                               'is_four': False,
#                               'is_six': False,
#                               'is_wicket': False,
#                               'wicket': None,
#                               'wicket_text': None},
#                              {'ball': 1,
#                               'runs': 0,
#                               'is_four': False,
#                               'is_six': False,
#                               'is_wicket': True,
#                               'wicket': 1,
#                               'wicket_text': 'caught'}],
#                             11: [{'ball': 6,
#                               'runs': 0,
#                               'is_four': False,
#                               'is_six': False,
#                               'is_wicket': False,
#                               'wicket': None,
#                               'wicket_text': None},
#                              {'ball': 5,
#                               'runs': 1,
#                               'is_four': False,
#                               'is_six': False,
#                               'is_wicket': False,
#                               'wicket': None,
#                               'wicket_text': None},
#                              {'ball': 4,
#                               'runs': 0,
#                               'is_four': False,
#                               'is_six': False,
#                               'is_wicket': True,
#                               'wicket': 1,
#                               'wicket_text': 'caught'},
#                              {'ball': 3,
#                               'runs': 1,
#                               'is_four': False,
#                               'is_six': False,
#                               'is_wicket': False,
#                               'wicket': None,
#                               'wicket_text': None},
#                              {'ball': 2,
#                               'runs': 0,
#                               'is_four': False,
#                               'is_six': False,
#                               'is_wicket': False,
#                               'wicket': None,
#                               'wicket_text': None},
#                              {'ball': 1,
#                               'runs': 0,
#                               'is_four': False,
#                               'is_six': False,
#                               'is_wicket': True,
#                               'wicket': 1,
#                               'wicket_text': 'caught'}],
#                             10: [{'ball': 6,
#                               'runs': 1,
#                               'is_four': False,
#                               'is_six': False,
#                               'is_wicket': False,
#                               'wicket': None,
#                               'wicket_text': None},
#                              {'ball': 5,
#                               'runs': 0,
#                               'is_four': False,
#                               'is_six': False,
#                               'is_wicket': False,
#                               'wicket': None,
#                               'wicket_text': None},
#                              {'ball': 4,
#                               'runs': 4,
#                               'is_four': True,
#                               'is_six': False,
#                               'is_wicket': False,
#                               'wicket': None,
#                               'wicket_text': None},
#                              {'ball': 3,
#                               'runs': 0,
#                               'is_four': False,
#                               'is_six': False,
#                               'is_wicket': False,
#                               'wicket': None,
#                               'wicket_text': None},
#                              {'ball': 2,
#                               'runs': 1,
#                               'is_four': False,
#                               'is_six': False,
#                               'is_wicket': False,
#                               'wicket': None,
#                               'wicket_text': None},
#                              {'ball': 1,
#                               'runs': 0,
#                               'is_four': False,
#                               'is_six': False,
#                               'is_wicket': False,
#                               'wicket': None,
#                               'wicket_text': None}],
#                             9: [{'ball': 6,
#                               'runs': 0,
#                               'is_four': False,
#                               'is_six': False,
#                               'is_wicket': False,
#                               'wicket': None,
#                               'wicket_text': None},
#                              {'ball': 5,
#                               'runs': 1,
#                               'is_four': False,
#                               'is_six': False,
#                               'is_wicket': False,
#                               'wicket': None,
#                               'wicket_text': None},
#                              {'ball': 4,
#                               'runs': 1,
#                               'is_four': False,
#                               'is_six': False,
#                               'is_wicket': False,
#                               'wicket': None,
#                               'wicket_text': None},
#                              {'ball': 3,
#                               'runs': 1,
#                               'is_four': False,
#                               'is_six': False,
#                               'is_wicket': False,
#                               'wicket': None,
#                               'wicket_text': None},
#                              {'ball': 2,
#                               'runs': 0,
#                               'is_four': False,
#                               'is_six': False,
#                               'is_wicket': False,
#                               'wicket': None,
#                               'wicket_text': None},
#                              {'ball': 1,
#                               'runs': 0,
#                               'is_four': False,
#                               'is_six': False,
#                               'is_wicket': False,
#                               'wicket': None,
#                               'wicket_text': None}],
#                             8: [{'ball': 6,
#                               'runs': 1,
#                               'is_four': False,
#                               'is_six': False,
#                               'is_wicket': False,
#                               'wicket': None,
#                               'wicket_text': None},
#                              {'ball': 5,
#                               'runs': 4,
#                               'is_four': True,
#                               'is_six': False,
#                               'is_wicket': False,
#                               'wicket': None,
#                               'wicket_text': None},
#                              {'ball': 4,
#                               'runs': 1,
#                               'is_four': False,
#                               'is_six': False,
#                               'is_wicket': False,
#                               'wicket': None,
#                               'wicket_text': None},
#                              {'ball': 3,
#                               'runs': 6,
#                               'is_four': False,
#                               'is_six': True,
#                               'is_wicket': False,
#                               'wicket': None,
#                               'wicket_text': None},
#                              {'ball': 2,
#                               'runs': 1,
#                               'is_four': False,
#                               'is_six': False,
#                               'is_wicket': False,
#                               'wicket': None,
#                               'wicket_text': None},
#                              {'ball': 1,
#                               'runs': 1,
#                               'is_four': False,
#                               'is_six': False,
#                               'is_wicket': False,
#                               'wicket': None,
#                               'wicket_text': None}],
#                             7: [{'ball': 6,
#                               'runs': 1,
#                               'is_four': False,
#                               'is_six': False,
#                               'is_wicket': False,
#                               'wicket': None,
#                               'wicket_text': None},
#                              {'ball': 5,
#                               'runs': 4,
#                               'is_four': True,
#                               'is_six': False,
#                               'is_wicket': False,
#                               'wicket': None,
#                               'wicket_text': None},
#                              {'ball': 4,
#                               'runs': 2,
#                               'is_four': False,
#                               'is_six': False,
#                               'is_wicket': False,
#                               'wicket': None,
#                               'wicket_text': None},
#                              {'ball': 3,
#                               'runs': 0,
#                               'is_four': False,
#                               'is_six': False,
#                               'is_wicket': False,
#                               'wicket': None,
#                               'wicket_text': None},
#                              {'ball': 2,
#                               'runs': 1,
#                               'is_four': False,
#                               'is_six': False,
#                               'is_wicket': False,
#                               'wicket': None,
#                               'wicket_text': None},
#                              {'ball': 1,
#                               'runs': 0,
#                               'is_four': False,
#                               'is_six': False,
#                               'is_wicket': False,
#                               'wicket': None,
#                               'wicket_text': None}],
#                             6: [{'ball': 7,
#                               'runs': 0,
#                               'is_four': False,
#                               'is_six': False,
#                               'is_wicket': False,
#                               'wicket': None,
#                               'wicket_text': None},
#                              {'ball': 6,
#                               'runs': 4,
#                               'is_four': True,
#                               'is_six': False,
#                               'is_wicket': False,
#                               'wicket': None,
#                               'wicket_text': None},
#                              {'ball': 5,
#                               'runs': 0,
#                               'is_four': False,
#                               'is_six': False,
#                               'is_wicket': False,
#                               'wicket': None,
#                               'wicket_text': None},
#                              {'ball': 4,
#                               'runs': 1,
#                               'is_four': False,
#                               'is_six': False,
#                               'is_wicket': False,
#                               'wicket': None,
#                               'wicket_text': None},
#                              {'ball': 3,
#                               'runs': 2,
#                               'is_four': False,
#                               'is_six': False,
#                               'is_wicket': False,
#                               'wicket': None,
#                               'wicket_text': None},
#                              {'ball': 2,
#                               'runs': 0,
#                               'is_four': False,
#                               'is_six': False,
#                               'is_wicket': False,
#                               'wicket': None,
#                               'wicket_text': None},
#                              {'ball': 1,
#                               'runs': 0,
#                               'is_four': False,
#                               'is_six': False,
#                               'is_wicket': False,
#                               'wicket': None,
#                               'wicket_text': None}],
#                             5: [{'ball': 6,
#                               'runs': 0,
#                               'is_four': False,
#                               'is_six': False,
#                               'is_wicket': False,
#                               'wicket': None,
#                               'wicket_text': None},
#                              {'ball': 5,
#                               'runs': 1,
#                               'is_four': False,
#                               'is_six': False,
#                               'is_wicket': False,
#                               'wicket': None,
#                               'wicket_text': None},
#                              {'ball': 4,
#                               'runs': 1,
#                               'is_four': False,
#                               'is_six': False,
#                               'is_wicket': False,
#                               'wicket': None,
#                               'wicket_text': None},
#                              {'ball': 3,
#                               'runs': 0,
#                               'is_four': False,
#                               'is_six': False,
#                               'is_wicket': False,
#                               'wicket': None,
#                               'wicket_text': None},
#                              {'ball': 2,
#                               'runs': 1,
#                               'is_four': False,
#                               'is_six': False,
#                               'is_wicket': False,
#                               'wicket': None,
#                               'wicket_text': None},
#                              {'ball': 1,
#                               'runs': 0,
#                               'is_four': False,
#                               'is_six': False,
#                               'is_wicket': False,
#                               'wicket': None,
#                               'wicket_text': None}],
#                             4: [{'ball': 6,
#                               'runs': 1,
#                               'is_four': False,
#                               'is_six': False,
#                               'is_wicket': False,
#                               'wicket': None,
#                               'wicket_text': None},
#                              {'ball': 5,
#                               'runs': 0,
#                               'is_four': False,
#                               'is_six': False,
#                               'is_wicket': False,
#                               'wicket': None,
#                               'wicket_text': None},
#                              {'ball': 4,
#                               'runs': 0,
#                               'is_four': False,
#                               'is_six': False,
#                               'is_wicket': False,
#                               'wicket': None,
#                               'wicket_text': None},
#                              {'ball': 3,
#                               'runs': 1,
#                               'is_four': False,
#                               'is_six': False,
#                               'is_wicket': False,
#                               'wicket': None,
#                               'wicket_text': None},
#                              {'ball': 2,
#                               'runs': 4,
#                               'is_four': True,
#                               'is_six': False,
#                               'is_wicket': False,
#                               'wicket': None,
#                               'wicket_text': None},
#                              {'ball': 1,
#                               'runs': 4,
#                               'is_four': True,
#                               'is_six': False,
#                               'is_wicket': False,
#                               'wicket': None,
#                               'wicket_text': None}],
#                             3: [{'ball': 7,
#                               'runs': 1,
#                               'is_four': False,
#                               'is_six': False,
#                               'is_wicket': False,
#                               'wicket': None,
#                               'wicket_text': None},
#                              {'ball': 6,
#                               'runs': 0,
#                               'is_four': False,
#                               'is_six': False,
#                               'is_wicket': False,
#                               'wicket': None,
#                               'wicket_text': None},
#                              {'ball': 5,
#                               'runs': 1,
#                               'is_four': False,
#                               'is_six': False,
#                               'is_wicket': False,
#                               'wicket': None,
#                               'wicket_text': None},
#                              {'ball': 4,
#                               'runs': 0,
#                               'is_four': False,
#                               'is_six': False,
#                               'is_wicket': False,
#                               'wicket': None,
#                               'wicket_text': None},
#                              {'ball': 3,
#                               'runs': 1,
#                               'is_four': False,
#                               'is_six': False,
#                               'is_wicket': False,
#                               'wicket': None,
#                               'wicket_text': None},
#                              {'ball': 2,
#                               'runs': 1,
#                               'is_four': False,
#                               'is_six': False,
#                               'is_wicket': False,
#                               'wicket': None,
#                               'wicket_text': None},
#                              {'ball': 1,
#                               'runs': 1,
#                               'is_four': False,
#                               'is_six': False,
#                               'is_wicket': False,
#                               'wicket': None,
#                               'wicket_text': None}],
#                             2: [{'ball': 8,
#                               'runs': 0,
#                               'is_four': False,
#                               'is_six': False,
#                               'is_wicket': False,
#                               'wicket': None,
#                               'wicket_text': None},
#                              {'ball': 7,
#                               'runs': 1,
#                               'is_four': False,
#                               'is_six': False,
#                               'is_wicket': False,
#                               'wicket': None,
#                               'wicket_text': None},
#                              {'ball': 6,
#                               'runs': 0,
#                               'is_four': False,
#                               'is_six': False,
#                               'is_wicket': False,
#                               'wicket': None,
#                               'wicket_text': None},
#                              {'ball': 5,
#                               'runs': 0,
#                               'is_four': False,
#                               'is_six': False,
#                               'is_wicket': False,
#                               'wicket': None,
#                               'wicket_text': None},
#                              {'ball': 4,
#                               'runs': 1,
#                               'is_four': False,
#                               'is_six': False,
#                               'is_wicket': False,
#                               'wicket': None,
#                               'wicket_text': None},
#                              {'ball': 3,
#                               'runs': 1,
#                               'is_four': False,
#                               'is_six': False,
#                               'is_wicket': False,
#                               'wicket': None,
#                               'wicket_text': None},
#                              {'ball': 2,
#                               'runs': 4,
#                               'is_four': True,
#                               'is_six': False,
#                               'is_wicket': False,
#                               'wicket': None,
#                               'wicket_text': None},
#                              {'ball': 1,
#                               'runs': 1,
#                               'is_four': False,
#                               'is_six': False,
#                               'is_wicket': False,
#                               'wicket': None,
#                               'wicket_text': None}],
#                             1: [{'ball': 6,
#                               'runs': 0,
#                               'is_four': False,
#                               'is_six': False,
#                               'is_wicket': False,
#                               'wicket': None,
#                               'wicket_text': None},
#                              {'ball': 5,
#                               'runs': 0,
#                               'is_four': False,
#                               'is_six': False,
#                               'is_wicket': False,
#                               'wicket': None,
#                               'wicket_text': None},
#                              {'ball': 4,
#                               'runs': 4,
#                               'is_four': True,
#                               'is_six': False,
#                               'is_wicket': False,
#                               'wicket': None,
#                               'wicket_text': None},
#                              {'ball': 3,
#                               'runs': 0,
#                               'is_four': False,
#                               'is_six': False,
#                               'is_wicket': False,
#                               'wicket': None,
#                               'wicket_text': None},
#                              {'ball': 2,
#                               'runs': 0,
#                               'is_four': False,
#                               'is_six': False,
#                               'is_wicket': False,
#                               'wicket': None,
#                               'wicket_text': None},
#                              {'ball': 1,
#                               'runs': 0,
#                               'is_four': False,
#                               'is_six': False,
#                               'is_wicket': False,
#                               'wicket': None,
#                               'wicket_text': None}]}),
#                2: defaultdict(list,
#                            {19: [{'ball': 4,
#                               'runs': 4,
#                               'is_four': True,
#                               'is_six': False,
#                               'is_wicket': False,
#                               'wicket': None,
#                               'wicket_text': None},
#                              {'ball': 3,
#                               'runs': 1,
#                               'is_four': False,
#                               'is_six': False,
#                               'is_wicket': False,
#                               'wicket': None,
#                               'wicket_text': None},
#                              {'ball': 2,
#                               'runs': 1,
#                               'is_four': False,
#                               'is_six': False,
#                               'is_wicket': False,
#                               'wicket': None,
#                               'wicket_text': None},
#                              {'ball': 1,
#                               'runs': 0,
#                               'is_four': False,
#                               'is_six': False,
#                               'is_wicket': False,
#                               'wicket': None,
#                               'wicket_text': None}],
#                             18: [{'ball': 6,
#                               'runs': 1,
#                               'is_four': False,
#                               'is_six': False,
#                               'is_wicket': False,
#                               'wicket': None,
#                               'wicket_text': None},
#                              {'ball': 5,
#                               'runs': 4,
#                               'is_four': True,
#                               'is_six': False,
#                               'is_wicket': False,
#                               'wicket': None,
#                               'wicket_text': None},
#                              {'ball': 4,
#                               'runs': 0,
#                               'is_four': False,
#                               'is_six': False,
#                               'is_wicket': False,
#                               'wicket': None,
#                               'wicket_text': None},
#                              {'ball': 3,
#                               'runs': 0,
#                               'is_four': False,
#                               'is_six': False,
#                               'is_wicket': False,
#                               'wicket': None,
#                               'wicket_text': None},
#                              {'ball': 2,
#                               'runs': 0,
#                               'is_four': False,
#                               'is_six': False,
#                               'is_wicket': True,
#                               'wicket': 1,
#                               'wicket_text': 'caught'},
#                              {'ball': 1,
#                               'runs': 0,
#                               'is_four': False,
#                               'is_six': False,
#                               'is_wicket': True,
#                               'wicket': 1,
#                               'wicket_text': 'caught'}],
#                             17: [{'ball': 6,
#                               'runs': 4,
#                               'is_four': True,
#                               'is_six': False,
#                               'is_wicket': False,
#                               'wicket': None,
#                               'wicket_text': None},
#                              {'ball': 5,
#                               'runs': 1,
#                               'is_four': False,
#                               'is_six': False,
#                               'is_wicket': False,
#                               'wicket': None,
#                               'wicket_text': None},
#                              {'ball': 4,
#                               'runs': 1,
#                               'is_four': False,
#                               'is_six': False,
#                               'is_wicket': False,
#                               'wicket': None,
#                               'wicket_text': None},
#                              {'ball': 3,
#                               'runs': 1,
#                               'is_four': False,
#                               'is_six': False,
#                               'is_wicket': False,
#                               'wicket': None,
#                               'wicket_text': None},
#                              {'ball': 2,
#                               'runs': 2,
#                               'is_four': False,
#                               'is_six': False,
#                               'is_wicket': False,
#                               'wicket': None,
#                               'wicket_text': None},
#                              {'ball': 1,
#                               'runs': 1,
#                               'is_four': False,
#                               'is_six': False,
#                               'is_wicket': False,
#                               'wicket': None,
#                               'wicket_text': None}],
#                             16: [{'ball': 6,
#                               'runs': 0,
#                               'is_four': False,
#                               'is_six': False,
#                               'is_wicket': False,
#                               'wicket': None,
#                               'wicket_text': None},
#                              {'ball': 5,
#                               'runs': 1,
#                               'is_four': False,
#                               'is_six': False,
#                               'is_wicket': False,
#                               'wicket': None,
#                               'wicket_text': None},
#                              {'ball': 4,
#                               'runs': 2,
#                               'is_four': False,
#                               'is_six': False,
#                               'is_wicket': False,
#                               'wicket': None,
#                               'wicket_text': None},
#                              {'ball': 3,
#                               'runs': 0,
#                               'is_four': False,
#                               'is_six': False,
#                               'is_wicket': False,
#                               'wicket': None,
#                               'wicket_text': None},
#                              {'ball': 2,
#                               'runs': 1,
#                               'is_four': False,
#                               'is_six': False,
#                               'is_wicket': False,
#                               'wicket': None,
#                               'wicket_text': None},
#                              {'ball': 1,
#                               'runs': 0,
#                               'is_four': False,
#                               'is_six': False,
#                               'is_wicket': True,
#                               'wicket': 3,
# ...
#                              {'ball': 4,
#                               'runs': 1,
#                               'is_four': False,
#                               'is_six': False,
#                               'is_wicket': False,
#                               'wicket': None,
#                               'wicket_text': None},
#                              {'ball': 3,
#                               'runs': 1,
#                               'is_four': False,
#                               'is_six': False,
#                               'is_wicket': False,
#                               'wicket': None,
#                               'wicket_text': None},
#                              {'ball': 2,
#                               'runs': 0,
#                               'is_four': False,
#                               'is_six': False,
#                               'is_wicket': False,
#                               'wicket': None,
#                               'wicket_text': None},
#                              {'ball': 1,
#                               'runs': 0,
#                               'is_four': False,
#                               'is_six': False,
#                               'is_wicket': False,
#                               'wicket': None,
#                               'wicket_text': None}],
#                             7: [{'ball': 6,
#                               'runs': 1,
#                               'is_four': False,
#                               'is_six': False,
#                               'is_wicket': False,
#                               'wicket': None,
#                               'wicket_text': None},
#                              {'ball': 5,
#                               'runs': 0,
#                               'is_four': False,
#                               'is_six': False,
#                               'is_wicket': True,
#                               'wicket': 2,
#                               'wicket_text': 'bowled'},
#                              {'ball': 4,
#                               'runs': 1,
#                               'is_four': False,
#                               'is_six': False,
#                               'is_wicket': False,
#                               'wicket': None,
#                               'wicket_text': None},
#                              {'ball': 3,
#                               'runs': 2,
#                               'is_four': False,
#                               'is_six': False,
#                               'is_wicket': False,
#                               'wicket': None,
#                               'wicket_text': None},
#                              {'ball': 2,
#                               'runs': 2,
#                               'is_four': False,
#                               'is_six': False,
#                               'is_wicket': False,
#                               'wicket': None,
#                               'wicket_text': None},
#                              {'ball': 1,
#                               'runs': 1,
#                               'is_four': False,
#                               'is_six': False,
#                               'is_wicket': False,
#                               'wicket': None,
#                               'wicket_text': None}],
#                             6: [{'ball': 6,
#                               'runs': 2,
#                               'is_four': False,
#                               'is_six': False,
#                               'is_wicket': False,
#                               'wicket': None,
#                               'wicket_text': None},
#                              {'ball': 5,
#                               'runs': 1,
#                               'is_four': False,
#                               'is_six': False,
#                               'is_wicket': False,
#                               'wicket': None,
#                               'wicket_text': None},
#                              {'ball': 4,
#                               'runs': 0,
#                               'is_four': False,
#                               'is_six': False,
#                               'is_wicket': False,
#                               'wicket': None,
#                               'wicket_text': None},
#                              {'ball': 3,
#                               'runs': 4,
#                               'is_four': True,
#                               'is_six': False,
#                               'is_wicket': False,
#                               'wicket': None,
#                               'wicket_text': None},
#                              {'ball': 2,
#                               'runs': 0,
#                               'is_four': False,
#                               'is_six': False,
#                               'is_wicket': False,
#                               'wicket': None,
#                               'wicket_text': None},
#                              {'ball': 1,
#                               'runs': 1,
#                               'is_four': False,
#                               'is_six': False,
#                               'is_wicket': False,
#                               'wicket': None,
#                               'wicket_text': None}],
#                             5: [{'ball': 8,
#                               'runs': 1,
#                               'is_four': False,
#                               'is_six': False,
#                               'is_wicket': False,
#                               'wicket': None,
#                               'wicket_text': None},
#                              {'ball': 7,
#                               'runs': 1,
#                               'is_four': False,
#                               'is_six': False,
#                               'is_wicket': False,
#                               'wicket': None,
#                               'wicket_text': None},
#                              {'ball': 6,
#                               'runs': 1,
#                               'is_four': False,
#                               'is_six': False,
#                               'is_wicket': False,
#                               'wicket': None,
#                               'wicket_text': None},
#                              {'ball': 5,
#                               'runs': 1,
#                               'is_four': False,
#                               'is_six': False,
#                               'is_wicket': False,
#                               'wicket': None,
#                               'wicket_text': None},
#                              {'ball': 4,
#                               'runs': 1,
#                               'is_four': False,
#                               'is_six': False,
#                               'is_wicket': False,
#                               'wicket': None,
#                               'wicket_text': None},
#                              {'ball': 3,
#                               'runs': 1,
#                               'is_four': False,
#                               'is_six': False,
#                               'is_wicket': False,
#                               'wicket': None,
#                               'wicket_text': None},
#                              {'ball': 2,
#                               'runs': 0,
#                               'is_four': False,
#                               'is_six': False,
#                               'is_wicket': False,
#                               'wicket': None,
#                               'wicket_text': None},
#                              {'ball': 1,
#                               'runs': 1,
#                               'is_four': False,
#                               'is_six': False,
#                               'is_wicket': False,
#                               'wicket': None,
#                               'wicket_text': None}],
#                             4: [{'ball': 7,
#                               'runs': 0,
#                               'is_four': False,
#                               'is_six': False,
#                               'is_wicket': False,
#                               'wicket': None,
#                               'wicket_text': None},
#                              {'ball': 6,
#                               'runs': 1,
#                               'is_four': False,
#                               'is_six': False,
#                               'is_wicket': False,
#                               'wicket': None,
#                               'wicket_text': None},
#                              {'ball': 5,
#                               'runs': 0,
#                               'is_four': False,
#                               'is_six': False,
#                               'is_wicket': False,
#                               'wicket': None,
#                               'wicket_text': None},
#                              {'ball': 4,
#                               'runs': 1,
#                               'is_four': False,
#                               'is_six': False,
#                               'is_wicket': False,
#                               'wicket': None,
#                               'wicket_text': None},
#                              {'ball': 3,
#                               'runs': 0,
#                               'is_four': False,
#                               'is_six': False,
#                               'is_wicket': False,
#                               'wicket': None,
#                               'wicket_text': None},
#                              {'ball': 2,
#                               'runs': 3,
#                               'is_four': False,
#                               'is_six': False,
#                               'is_wicket': False,
#                               'wicket': None,
#                               'wicket_text': None},
#                              {'ball': 1,
#                               'runs': 0,
#                               'is_four': False,
#                               'is_six': False,
#                               'is_wicket': True,
#                               'wicket': 1,
#                               'wicket_text': 'caught'}],
#                             3: [{'ball': 6,
#                               'runs': 1,
#                               'is_four': False,
#                               'is_six': False,
#                               'is_wicket': False,
#                               'wicket': None,
#                               'wicket_text': None},
#                              {'ball': 5,
#                               'runs': 0,
#                               'is_four': False,
#                               'is_six': False,
#                               'is_wicket': False,
#                               'wicket': None,
#                               'wicket_text': None},
#                              {'ball': 4,
#                               'runs': 0,
#                               'is_four': False,
#                               'is_six': False,
#                               'is_wicket': False,
#                               'wicket': None,
#                               'wicket_text': None},
#                              {'ball': 3,
#                               'runs': 1,
#                               'is_four': False,
#                               'is_six': False,
#                               'is_wicket': False,
#                               'wicket': None,
#                               'wicket_text': None},
#                              {'ball': 2,
#                               'runs': 0,
#                               'is_four': False,
#                               'is_six': False,
#                               'is_wicket': False,
#                               'wicket': None,
#                               'wicket_text': None},
#                              {'ball': 1,
#                               'runs': 1,
#                               'is_four': False,
#                               'is_six': False,
#                               'is_wicket': False,
#                               'wicket': None,
#                               'wicket_text': None}],
#                             2: [{'ball': 6,
#                               'runs': 0,
#                               'is_four': False,
#                               'is_six': False,
#                               'is_wicket': False,
#                               'wicket': None,
#                               'wicket_text': None},
#                              {'ball': 5,
#                               'runs': 1,
#                               'is_four': False,
#                               'is_six': False,
#                               'is_wicket': False,
#                               'wicket': None,
#                               'wicket_text': None},
#                              {'ball': 4,
#                               'runs': 0,
#                               'is_four': False,
#                               'is_six': False,
#                               'is_wicket': False,
#                               'wicket': None,
#                               'wicket_text': None},
#                              {'ball': 3,
#                               'runs': 4,
#                               'is_four': True,
#                               'is_six': False,
#                               'is_wicket': False,
#                               'wicket': None,
#                               'wicket_text': None},
#                              {'ball': 2,
#                               'runs': 0,
#                               'is_four': False,
#                               'is_six': False,
#                               'is_wicket': False,
#                               'wicket': None,
#                               'wicket_text': None},
#                              {'ball': 1,
#                               'runs': 4,
#                               'is_four': True,
#                               'is_six': False,
#                               'is_wicket': False,
#                               'wicket': None,
#                               'wicket_text': None}],
#                             1: [{'ball': 6,
#                               'runs': 0,
#                               'is_four': False,
#                               'is_six': False,
#                               'is_wicket': False,
#                               'wicket': None,
#                               'wicket_text': None},
#                              {'ball': 5,
#                               'runs': 4,
#                               'is_four': True,
#                               'is_six': False,
#                               'is_wicket': False,
#                               'wicket': None,
#                               'wicket_text': None},
#                              {'ball': 4,
#                               'runs': 4,
#                               'is_four': True,
#                               'is_six': False,
#                               'is_wicket': False,
#                               'wicket': None,
#                               'wicket_text': None},
#                              {'ball': 3,
#                               'runs': 1,
#                               'is_four': False,
#                               'is_six': False,
#                               'is_wicket': False,
#                               'wicket': None,
#                               'wicket_text': None},
#                              {'ball': 2,
#                               'runs': 1,
#                               'is_four': False,
#                               'is_six': False,
#                               'is_wicket': False,
#                               'wicket': None,
#                               'wicket_text': None},
#                              {'ball': 1,
#                               'runs': 1,
#                               'is_four': False,
#                               'is_six': False,
#                               'is_wicket': False,
#                               'wicket': None,
#                               'wicket_text': None}]})})}]

# %%
b = get_row_list_from_all_match_data(a,2020)

# %%
df = pd.DataFrame(b)

# %%
df = df[
    [
        "psl_year",
        "match_number",
        "team_1",
        "team_2",
        "inning",
        "over",
        "ball",
        "runs",
        "wicket",
        "total_runs",
        "wickets",
        "is_four",
        "is_six",
        "is_wicket",
        "wicket_text",
        "result",
    ]
]

# %%
df.to_csv("missing.csv", index=False)
