# %%
import requests
from urllib.parse import urlparse
from bs4 import BeautifulSoup
import json
from furl import furl
from collections import defaultdict
import pandas as pd
import copy
import time

# %%
# URL to result pages of all the years of PSL
# You can replace these with URLS to some other series result pages and the script should worl
psl_urls = {
    "2016":"https://www.espncricinfo.com/series/pakistan-super-league-2015-16-923069/match-results",
    "2017":"https://www.espncricinfo.com/series/psl-2016-17-1075974/match-results",
    "2018":"https://www.espncricinfo.com/series/psl-2017-18-1128817/match-results",
    "2019":"https://www.espncricinfo.com/series/psl-2018-19-1168814/match-results",
    "2020":"https://www.espncricinfo.com/series/psl-2019-20-2020-21-1211602/match-results"
}

# %%
# Extracting all Data
start = time.time()
all_rows = []
for psl_year, url in psl_urls.items():
    psl_data = get_psl_data_for_year(psl_year, url)
    all_rows.extend(psl_data)
end = time.time()

print (f"Total Time Taken : {end-start}")
# Out:
# https://www.espncricinfo.com/series/pakistan-super-league-2015-16-923069/islamabad-united-vs-quetta-gladiators-final-959221/live-cricket-score
# https://www.espncricinfo.com/series/pakistan-super-league-2015-16-923069/islamabad-united-vs-peshawar-zalmi-3rd-qualifying-final-959219/live-cricket-score
# https://www.espncricinfo.com/series/pakistan-super-league-2015-16-923069/islamabad-united-vs-karachi-kings-2nd-qualifying-final-959217/live-cricket-score
# https://www.espncricinfo.com/series/pakistan-super-league-2015-16-923069/peshawar-zalmi-vs-quetta-gladiators-1st-qualifying-final-959215/live-cricket-score
# https://www.espncricinfo.com/series/pakistan-super-league-2015-16-923069/islamabad-united-vs-lahore-qalandars-20th-match-959213/live-cricket-score
# https://www.espncricinfo.com/series/pakistan-super-league-2015-16-923069/karachi-kings-vs-peshawar-zalmi-19th-match-959211/live-cricket-score
# https://www.espncricinfo.com/series/pakistan-super-league-2015-16-923069/lahore-qalandars-vs-quetta-gladiators-18th-match-959209/live-cricket-score
# https://www.espncricinfo.com/series/pakistan-super-league-2015-16-923069/quetta-gladiators-vs-peshawar-zalmi-17th-match-959207/live-cricket-score
# https://www.espncricinfo.com/series/pakistan-super-league-2015-16-923069/islamabad-united-vs-karachi-kings-16th-match-959205/live-cricket-score
# https://www.espncricinfo.com/series/pakistan-super-league-2015-16-923069/lahore-qalandars-vs-peshawar-zalmi-15th-match-959203/live-cricket-score
# https://www.espncricinfo.com/series/pakistan-super-league-2015-16-923069/karachi-kings-vs-quetta-gladiators-14th-match-959201/live-cricket-score
# https://www.espncricinfo.com/series/pakistan-super-league-2015-16-923069/islamabad-united-vs-peshawar-zalmi-13th-match-959199/live-cricket-score
# https://www.espncricinfo.com/series/pakistan-super-league-2015-16-923069/karachi-kings-vs-lahore-qalandars-12th-match-959197/live-cricket-score
# https://www.espncricinfo.com/series/pakistan-super-league-2015-16-923069/islamabad-united-vs-quetta-gladiators-11th-match-959195/live-cricket-score
# https://www.espncricinfo.com/series/pakistan-super-league-2015-16-923069/karachi-kings-vs-peshawar-zalmi-10th-match-959193/live-cricket-score
# https://www.espncricinfo.com/series/pakistan-super-league-2015-16-923069/islamabad-united-vs-lahore-qalandars-9th-match-959191/live-cricket-score
# https://www.espncricinfo.com/series/pakistan-super-league-2015-16-923069/lahore-qalandars-vs-quetta-gladiators-8th-match-959189/live-cricket-score
# https://www.espncricinfo.com/series/pakistan-super-league-2015-16-923069/quetta-gladiators-vs-peshawar-zalmi-7th-match-959187/live-cricket-score
# https://www.espncricinfo.com/series/pakistan-super-league-2015-16-923069/islamabad-united-vs-karachi-kings-6th-match-959185/live-cricket-score
# https://www.espncricinfo.com/series/pakistan-super-league-2015-16-923069/lahore-qalandars-vs-peshawar-zalmi-5th-match-959183/live-cricket-score
# https://www.espncricinfo.com/series/pakistan-super-league-2015-16-923069/quetta-gladiators-vs-karachi-kings-4th-match-959181/live-cricket-score
# https://www.espncricinfo.com/series/pakistan-super-league-2015-16-923069/peshawar-zalmi-vs-islamabad-united-3rd-match-959179/live-cricket-score
# https://www.espncricinfo.com/series/pakistan-super-league-2015-16-923069/karachi-kings-vs-lahore-qalandars-2nd-match-959177/live-cricket-score
# https://www.espncricinfo.com/series/pakistan-super-league-2015-16-923069/islamabad-united-vs-quetta-gladiators-1st-match-959175/live-cricket-score
#  JSON DUMP DATA LEN : 24
# https://www.espncricinfo.com/series/psl-2016-17-1075974/peshawar-zalmi-vs-quetta-gladiators-final-1076009/live-cricket-score
# https://www.espncricinfo.com/series/psl-2016-17-1075974/karachi-kings-vs-peshawar-zalmi-3rd-qualifying-final-1076008/live-cricket-score
# https://www.espncricinfo.com/series/psl-2016-17-1075974/islamabad-united-vs-karachi-kings-2nd-qualifying-final-1076007/live-cricket-score
# https://www.espncricinfo.com/series/psl-2016-17-1075974/peshawar-zalmi-vs-quetta-gladiators-1st-qualifying-final-1076006/live-cricket-score
# https://www.espncricinfo.com/series/psl-2016-17-1075974/islamabad-united-vs-karachi-kings-20th-match-1076005/live-cricket-score
# https://www.espncricinfo.com/series/psl-2016-17-1075974/peshawar-zalmi-vs-quetta-gladiators-19th-match-1076004/live-cricket-score
# https://www.espncricinfo.com/series/psl-2016-17-1075974/karachi-kings-vs-lahore-qalandars-18th-match-1076003/live-cricket-score
# https://www.espncricinfo.com/series/psl-2016-17-1075974/islamabad-united-vs-quetta-gladiators-17th-match-1076002/live-cricket-score
# https://www.espncricinfo.com/series/psl-2016-17-1075974/lahore-qalandars-vs-peshawar-zalmi-16th-match-1076001/live-cricket-score
# https://www.espncricinfo.com/series/psl-2016-17-1075974/karachi-kings-vs-quetta-gladiators-15th-match-1076000/live-cricket-score
# https://www.espncricinfo.com/series/psl-2016-17-1075974/islamabad-united-vs-lahore-qalandars-14th-match-1075999/live-cricket-score
# https://www.espncricinfo.com/series/psl-2016-17-1075974/karachi-kings-vs-peshawar-zalmi-13th-match-1075998/live-cricket-score
# https://www.espncricinfo.com/series/psl-2016-17-1075974/islamabad-united-vs-peshawar-zalmi-12th-match-1075997/live-cricket-score
# https://www.espncricinfo.com/series/psl-2016-17-1075974/lahore-qalandars-vs-quetta-gladiators-11th-match-1075996/live-cricket-score
# https://www.espncricinfo.com/series/psl-2016-17-1075974/islamabad-united-vs-karachi-kings-10th-match-1075995/live-cricket-score
# https://www.espncricinfo.com/series/psl-2016-17-1075974/peshawar-zalmi-vs-quetta-gladiators-9th-match-1075994/live-cricket-score
# https://www.espncricinfo.com/series/psl-2016-17-1075974/karachi-kings-vs-lahore-qalandars-8th-match-1075993/live-cricket-score
# https://www.espncricinfo.com/series/psl-2016-17-1075974/islamabad-united-vs-quetta-gladiators-7th-match-1075992/live-cricket-score
# https://www.espncricinfo.com/series/psl-2016-17-1075974
    return get_row_list_from_all_match_data(all_match_data, psl_year)

# %%
# Givn a PSL result page, get URL for all matches
def get_all_url_for_psl_url(url):
    content = requests.get(url).text
    soup = BeautifulSoup(content)
    main_div = soup.find("div",{"class":"league-scores-container"}).find("div",{"class":"no-gutters"})
    url_list = []
    for div in main_div:
        wrong_url = div.find("a")["href"]
        parsed = urllib.parse.urlparse(wrong_url)
        replaced = parsed._replace(netloc="www.espncricinfo.com")
        url_list.append(replaced.geturl())
    return url_list

# %%
# Given a match URL, get all of its data
def get_all_matches_data_from_url_list(url_list):
    all_match_data =[]
    for match_url in url_list:
        print(match_url)
        url_split = match_url.split("/")
        series_id = url_split[4].split("-")[-1]
        match_id = url_split[5].split("-")[-1]
        match_data = defaultdict(int)
        team1, team2, result= get_winner_name(match_url)
        for inning_number in range(1,3):
            score_url =f"https://hs-consumer-api.espncricinfo.com/v1/pages/match/comments?seriesId={series_id}&matchId={match_id}&inningNumber={inning_number}&commentType=ALL"
            match_data[inning_number] =get_data_for_url(score_url)
        all_match_data.append({
            "team_1": team1,
            "team_2": team2,
            "result": result,
            "data": match_data
        })
    return all_match_data

# %%
# Get the winner name from the header
def get_winner_name(url):
    content = requests.get(url).text
    soup = BeautifulSoup(content)
    match_info = soup.find("div",{"class":"match-info-MATCH"})
    winner = match_info.find("div",{"class":"status-text"})
    teams = match_info.find("div",{"class":"teams"})
    team1, team2 = teams.find_all("a",{"class":"name-link"})
    team1= team1.text
    team2= team2.text
    if "abandoned" in winner.text:
        return team1, team2, "abondoned"
    elif "tied" in winner.text:
        return team1, team2, "tied"
    elif "No result" in winner.text:
        return team1, team2 , "no_result"
    else:
        return team1, team2, winner.text.split(" ")[0]

# %%
# Given a URL for an API call, get all of its Data
def get_data_for_url(url):
    overs = defaultdict(list)
    previous_over = 20
    next_over = "stuf"
    while (next_over):
        content = requests.get(url)
        next_over = content.json().get("nextInningOver")
        json_data = content.json()
        for comment in json_data.get("comments"):
            over= comment.get("overNumber")
            wicket_text = comment.get("dismissalText")
            if wicket_text :
                wicket_text = wicket_text.get("short")
            ball_obj = {
                "ball": comment.get("ballNumber"),
                "runs" : comment.get("totalRuns"),
                "is_four" : comment.get("isFour"),
                "is_six" : comment.get("isSix"),
                "is_wicket" : comment.get("isWicket"),
                "wicket": comment.get("dismissalType"),
                "wicket_text": wicket_text

            }
            overs[over].append(ball_obj)
        if f"fromInningOver={previous_over}" in url:
           
            url =url.replace(f"fromInningOver={previous_over}",f"fromInningOver={next_over}")
        else:
            url = f"{url}&fromInningOver={next_over}"
       
        previous_over=next_over
        
    return overs

# %%
# Given all Data, Generate the rows for the CSV from extracted data
def get_row_list_from_all_match_data(all_match_data, psl_year):
    all_rows = []
    for index , match in enumerate(reversed(all_match_data)):
        for ining, value in match["data"].items():
            wickets =0
            runs =0 
            for over in range (1,21):
                if over in value:
                    for ball_result in reversed(value[over]):
                        row ={}
                        runs = runs+ (ball_result["runs"])
                        ball = ball_result["ball"]
                        if ball_result["is_wicket"]:
                            wickets +=1
                        row = copy.deepcopy(ball_result)
                        row["psl_year"]=psl_year
                        row["match_number"] = index+1
                        row["over"]=over
                        row["inning"]=ining
                        row["team_1"] = match["team_1"]
                        row["team_2"] = match["team_2"]
                        row["result"] = match["result"]
                        row["total_runs"] = runs
                        row["wickets"]= wickets
                        all_rows.append(row)
    return all_rows

# %%
df.head(20)
# Out:
#     ball  runs  is_four  is_six  is_wicket  wicket wicket_text psl_year  \
# 0      1     0    False   False      False     NaN        None     2016
# 1      2     0    False   False      False     NaN        None     2016
# 2      3     0    False   False      False     NaN        None     2016
# 3      4     0    False   False      False     NaN        None     2016
# 4      5     0    False   False      False     NaN        None     2016
# 5      6     0    False   False      False     NaN        None     2016
# 6      1     0    False   False      False     NaN        None     2016
# 7      2     1    False   False      False     NaN        None     2016
# 8      3     2    False   False      False     NaN        None     2016
# 9      4     0    False   False      False     NaN        None     2016
# 10     5     0    False   False      False     NaN        None     2016
# 11     6     2    False   False      False     NaN        None     2016
# 12     1     1    False   False      False     NaN        None     2016
# 13     2     4     True   False      False     NaN        None     2016
# 14     3     0    False   False      False     NaN        None     2016
# 15     4     0    False   False      False     NaN        None     2016
# 16     5     0    False   False      False     NaN        None     2016
# 17     6     1    False   False      False     NaN        None     2016
# 18     1     0    False   False      False     NaN        None     2016
# 19     2     0    False   False      False     NaN        None     2016
#
#     match_number  over  inning            team_1             team_2  \
# 0              1     1       1  Islamabad United  Quetta Gladiators
# 1              1     1       1  Islamabad United  Quetta Gladiators
# 2              1     1       1  Islamabad United  Quetta Gladiators
# 3              1     1       1  Islamabad United  Quetta Gladiators
# 4              1     1       1  Islamabad United  Quetta Gladiators
# 5              1     1       1  Islamabad United  Quetta Gladiators
# 6              1     2       1  Islamabad United  Quetta Gladiators
# 7              1     2       1  Islamabad United  Quetta Gladiators
# 8              1     2       1  Islamabad United  Quetta Gladiators
# 9              1     2       1  Islamabad United  Quetta Gladiators
# 10             1     2       1  Islamabad United  Quetta Gladiators
# 11             1     2       1  Islamabad United  Quetta Gladiators
# 12             1     3       1  Islamabad United  Quetta Gladiators
# 13             1     3       1  Islamabad United  Quetta Gladiators
# 14             1     3       1  Islamabad United  Quetta Gladiators
# 15             1     3       1  Islamabad United  Quetta Gladiators
# 16             1     3       1  Islamabad United  Quetta Gladiators
# 17             1     3       1  Islamabad United  Quetta Gladiators
# 18             1     4       1  Islamabad United  Quetta Gladiators
# 19             1     4       1  Islamabad United  Quetta Gladiators
#
#         result  total_runs  wickets
# 0   Gladiators           0        0
# 1   Gladiators           0        0
# 2   Gladiators           0        0
# 3   Gladiators           0        0
# 4   Gladiators           0        0
# 5   Gladiators           0        0
# 6   Gladiators           0        0
# 7   Gladiators           1        0
# 8   Gladiators           3        0
# 9   Gladiators           3        0
# 10  Gladiators           3        0
# 11  Gladiators           5        0
# 12  Gladiators           6        0
# 13  Gladiators          10        0
# 14  Gladiators          10        0
# 15  Gladiators          10        0
# 16  Gladiators          10        0
# 17  Gladiators          11        0
# 18  Gladiators          11        0
# 19  Gladiators          11        0
